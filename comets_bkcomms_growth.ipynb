# %%
# %load_ext autoreload
# %autoreload 2
from bk_comms.community import Community
import numpy as np
from bk_comms.simulator import TimeSeriesSimulation
import matplotlib.pyplot as plt
import seaborn as sns
import os
from bk_comms import utils
os.environ['GUROBI_HOME'] = "/Library/gurobi912/mac64"
os.environ['GUROBI_COMETS_HOME'] = "/Library/gurobi912/mac64"
os.environ['COMETS_HOME'] = "/Users/bezk/Documents/CAM/research_code/comets_2.10.5_linux" 
os.environ['COMETS_HOME'] = "/Users/bezk/Documents/CAM/research_code/comets" 
os.environ['JAVA_HOME'] = "/Library/Java/JavaVirtualMachines/jdk-17.0.1.jdk/Contents/Home"

# %%
wd = './'

model_names = ['L_lactis_fbc_delGLUSx_delGLUSy', 'iMM904']
model_paths = [f"{wd}/models/L_lactis/L_lactis_fbc_delGLUSx_delGLUSy.xml",
  f"{wd}/models/S_cerevisiae/iMM904.xml"]
smetana_analysis_path = f"{wd}/carveme_output/L_lactis_fbc_delGLUSx_delGLUSy_detailed.tsv"
media_path = f"{wd}/media/media_db_CDM35.tsv"
media_name = 'CDM35'
use_parsimonius_fba = False
initial_populations = [0.0039, 0.0062]


model_names = ['iMM904']
model_paths = [f"{wd}/models/S_cerevisiae/iMM904.xml"]
smetana_analysis_path = f"{wd}/carveme_output/L_lactis_fbc_delGLUSx_delGLUSy_detailed.tsv"
media_path = f"{wd}/media/media_db_CDM35.tsv"
media_name = 'CDM35'
use_parsimonius_fba = False
initial_populations = [0.0062]

model_names = ['E_coli_IAI1']
model_paths = [f"{wd}/models/melanie_data_models/E_coli_IAI1.xml"]
smetana_analysis_path = f"{wd}/smetana_analysis/melanie_data_detailed.tsv"
media_path = f"{wd}/media/melanie_data_media.tsv"
media_name = 'M2'
use_parsimonius_fba = False
initial_populations = [0.0005]


comm_1 = Community(model_names,
        model_paths,
        smetana_analysis_path,
        media_path,
        media_name,
        use_parsimonius_fba,
        initial_populations
)
# Out:
# Total env compounds: 330
# Crossfeeding compounds: 58754
# Competition compounds: 125
# Media compounds: 43
# Dynamic compounds: 168
# Defined in media file and model media EX_glc__D_e
# Defined in media file and model media EX_h2o_e
# Defined in media file and model media EX_h_e
# Defined in media file and model media EX_leu__L_e
# Defined in media file and model media EX_ala__L_e
# Defined in media file and model media EX_cl_e
# Defined in media file and model media EX_ac_e
# Defined in media file and model media EX_pi_e
# Defined in media file and model media EX_nh4_e
# Defined in media file and model media EX_ade_e
# Defined in media file and model media EX_asn__L_e
# Defined in media file and model media EX_cys__L_e
# Defined in media file and model media EX_gln__L_e
# Defined in media file and model media EX_gly_e
# Defined in media file and model media EX_ser__L_e
# Defined in media file and model media EX_thr__L_e
# Defined in media file and model media EX_arg__L_e
# Defined in media file and model media EX_fe3_e
# Defined in media file and model media EX_lys__L_e
# Defined in media file and model media EX_ascb__L_e
# Defined in media file and model media EX_asp__L_e
# Defined in media file and model media EX_phe__L_e
# Defined in media file and model media EX_k_e
# Defined in media file and model media EX_pro__L_e
# Defined in media file and model media EX_ca2_e
# Defined in media file and model media EX_cit_e
# Defined in media file and model media EX_mg2_e
# Defined in media file and model media EX_mn2_e
# Defined in media file and model media EX_cobalt2_e
# Defined in media file and model media EX_zn2_e
# Defined in media file and model media EX_cu2_e
# Defined in media file and model media EX_glu__L_e
# Defined in media file and model media EX_fe2_e
# Defined in media file and model media EX_gthrd_e
# Defined in media file and model media EX_gua_e
# Defined in media file and model media EX_his__L_e
# Defined in media file and model media EX_ile__L_e
# Defined in media file and model media EX_inost_e
# Defined in media file and model media EX_lipoate_e
# Defined in media file and model media EX_met__L_e
# Defined in media file and model media EX_mobd_e
# Defined in media file and model media EX_nac_e
# Defined in media file and model media EX_pnto__R_e
# Defined in media file and model media EX_pydam_e
# Defined in media file and model media EX_pydxn_e
# Defined in media file and model media EX_so4_e
# Defined in media file and model media EX_trp__L_e
# Defined in media file and model media EX_tyr__L_e
# Defined in media file and model media EX_val__L_e
# Defined in media file and model media EX_thm_e
# Defined in media file and model media EX_ura_e
# Defined in media file and model media EX_xan_e

# %%
import cometspy
import pandas as pd
pd.set_option('display.max_rows', None)
cometspy.params().show_params()
# Out:
#                                                VALUE  \
# BiomassLogName                               biomass
# BiomassLogRate                                     1
# FluxLogName                                 flux_out
# FluxLogRate                                        5
# MediaLogName                               media_out
# MediaLogRate                                       5
# SpecificMediaLogName                  specific_media
# TotalBiomassLogName                total_biomass_out
# activateRate                                   0.001
# addRate                                            0
# allowCellOverlap                                True
# batchDilution                                  False
# biomassLogFormat                              COMETS
# biomassMotionStyle      Diffusion 2D(Crank-Nicolson)
# cellSize                                         0.0
# colorRelative                                   True
# costlyGenome                                   False
# deathRate                                          0
# defaultAlpha                                       1
# defaultDiffConst                             0.00001
# defaultHill                                        1
# defaultKm                                       0.01
# defaultVmax                                       10
# defaultW                                          10
# dilFactor                                         10
# dilTime                                            2
# evolution                                      False
# exchangestyle                            Monod Style
# flowDiffRate                                     0.0
# fluxLogFormat                                 COMETS
# geneFractionalCost                            0.0001
# growthDiffRate                                     0
# maxCycles                                        100
# maxSpaceBiomass                                  0.1
# mediaLogFormat                                COMETS
# metaboliteDilutionRate                           0.0
# minSpaceBiomass                                  0.0
# mutRate                                            0
# numDiffPerStep                                    10
# numExRxnSubsteps                                   5
# numRunThreads                                      1
# randomSeed                                         0
# saveslideshow                                  False
# showCycleCount                                  True
# showCycleTime                                  False
# simulateActivation                             False
# slideshowColorRelative                          True
# slideshowExt                                     png
# slideshowLayer                                     0
# slideshowRate                                      1
# spaceWidth                                      0.02
# specificMedia                                   ac_e
# specificMediaLogRate                               1
# timeStep                                         0.1
# toroidalWorld                                  False
# totalBiomassLogRate                                1
# useLogNameTimeStamp                            False
# writeBiomassLog                                False
# writeFluxLog                                   False
# writeMediaLog                                  False
# writeSpecificMediaLog                          False
# writeTotalBiomassLog                            True
#
#                                                       UNITS
# BiomassLogName
# BiomassLogRate                                       cycles
# FluxLogName
# FluxLogRate                                          cycles
# MediaLogName
# MediaLogRate                                         cycles
# SpecificMediaLogName
# TotalBiomassLogName
# activateRate
# addRate                               additions /generation
# allowCellOverlap                                    logical
# batchDilution                                       logical
# biomassLogFormat
# biomassMotionStyle                           type of motion
# cellSize                                gr. cell dry weight
# colorRelative                                       logical
# costlyGenome                                        logical
# deathRate                                     percent/cycle
# defaultAlpha                                          slope
# defaultDiffConst                                      cm2/s
# defaultHill                                        unitless
# defaultKm                                   M (molar conc.)
# defaultVmax                               mmol /gr. CDW /hr
# defaultW                                    M (molar conc.)
# dilFactor
# dilTime                                                 hr.
# evolution                                           logical
# exchangestyle                                   uptake type
# flowDiffRate                                          cm2/s
# fluxLogFormat
# geneFractionalCost      percent growth rate^(1/2) /reaction
# growthDiffRate                                        cm2/s
# maxCycles                                            cycles
# maxSpaceBiomass                         gr. cell dry weight
# mediaLogFormat
# metaboliteDilutionRate                        percent/cycle
# minSpaceBiomass                         gr. cell dry weight
# mutRate                     deletions /reaction /generation
# numDiffPerStep
# numExRxnSubsteps                                    numeric
# numRunThreads
# randomSeed                                          numeric
# saveslideshow                                       logical
# showCycleCount                                      logical
# showCycleTime                                       logical
# simulateActivation                                  logical
# slideshowColorRelative                              logical
# slideshowExt                                      extension
# slideshowLayer                                      numeric
# slideshowRate                                        cycles
# spaceWidth                                               cm
# specificMedia                        comma separated string
# specificMediaLogRate                                 cycles
# timeStep                                                hr.
# toroidalWorld                                       logical
# totalBiomassLogRate                                  cycles
# useLogNameTimeStamp                                 logical
# writeBiomassLog                                     logical
# writeFluxLog                                        logical
# writeMediaLog                                       logical
# writeSpecificMediaLog                               logical
# writeTotalBiomassLog                                logical

# %%
from bk_comms import simulator

gurobi_home_dir = "/Library/gurobi950/macos_universal2"
comets_home_dir = "/Users/bezk/Documents/CAM/research_code/comets" 


simulator = simulator.CometsTimeSeriesSimulation(t_end=24.0, dt=0.01, 
                                                 gurobi_home_dir= gurobi_home_dir, 
                                                 comets_home_dir=comets_home_dir)

comets_lib = '/Users/bezk/Documents/CAM/research_code/comets/lib'
java_lib = ''

# %%
simulator.simulate_particles([comm_1], n_processes=3)

# layout, experiment = simulator.simulate_particles([comm, comm, comm], n_processes=2)
# experiment.set_classpath("concurrent", "/opt/colt/lib/concurrent.jar")
# experiment.set_classpath("colt", f"{comets_lib}/colt/colt.jar")
# experiment.set_classpath("lang3", f"{comets_lib}/commons-lang3-3.9/commons-lang3-3.9.jar")
# experiment.set_classpath("jmatio",f"{comets_lib}/jmatio/lib/jmatio.jar")
# experiment.set_classpath("math3",f"{comets_lib}/commons-math3-3.6.1/commons-math3-3.6.1.jar")
# experiment.set_classpath("bin","/Users/bezk/Documents/CAM/research_code/comets/bin/comets.jar")
# experiment.set_classpath("gurobi", "/Library/gurobi950/macos_universal2/lib/gurobi.jar")
# experiment.set_classpath("jdistlib", f"{comets_lib}/jdistlib-0.4.5-bin.jar")
# Out:
# running parallel
# building empty layout model
# models will need to be added with layout.add_model()
# Warning: The added metabolite (abt__L_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (id3acald_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (fol_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (chor_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (6pgc_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (citr__L_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (udcpdp_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (pep_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (glucan4_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (glucan6_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (man1p_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (4abz_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (gthox_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (murein5p5p_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (xylan4_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (coa_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (pheme_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (hco3_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (lmn2_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (murein5p5p5p_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (murein5p4p_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (xylan8_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (murein5px4p_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (murein5px4px4p_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (ribflv_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (btn_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (ni2_e) is notable to be taken up by any of the current models
# Warning: The added metabolite (na1_e) is notable to be taken up by any of the current models
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# reaction couldnt be found
# Warning: java class libraries cannot be found
# These are the expected locations for dependencies:
# Dependency 			 expected path
# __________ 			 _____________
# jdistlib			/Users/bezk/Documents/CAM/research_code/comets/lib/jdistlib
# bin			/Users/bezk/Documents/CAM/research_code/comets/bin/edu.jar
#
#   You have two options to fix this problem:
# 1.  set each class path correctly by doing:
#     comets.set_classpath(libraryname, path)
#     e.g.   comets.set_classpath('hamcrest', '/home/chaco001/comets/junit/hamcrest-core-1.3.jar')
#
#     note that versions dont always have to exactly match, but you're on your own if they don't
#
# 2.  fully define the classpath yourself by overwriting comets.JAVA_CLASSPATH
#        look at the current comets.JAVA_CLASSPATH to see how this should look.
#
# Running COMETS simulation ...
# COMETSpy:  False
# 5e-06
# <class 'numpy.float64'>
# Model file:  model_file ./E_coli_IAI1.cmd
#
# ['E_coli_IAI1']
# Done!
# Terminating pool

# %%
comm_1.populations[0].model.medium
# Out:
# {'EX_glc__D_e': 83.261229108925,
#  'EX_h2o_e': 555083.7343813314,
#  'EX_h_e': 15.764827271464572,
#  'EX_leu__L_e': 7.62352240888671,
#  'EX_ala__L_e': 4.489679461579681,
#  'EX_cl_e': 1194.1544649631765,
#  'EX_ac_e': 30.0,
#  'EX_pi_e': 100.87251567209314,
#  'EX_nh4_e': 110.97697315883916,
#  'EX_ade_e': 0.0814049608183122,
#  'EX_asn__L_e': 3.784495678105936,
#  'EX_cys__L_e': 1.650737054094653,
#  'EX_gln__L_e': 4.105523448081345,
#  'EX_gly_e': 3.996449021829136,
#  'EX_ser__L_e': 4.757708010324607,
#  'EX_thr__L_e': 4.197476141545612,
#  'EX_arg__L_e': 4.13315652608194,
#  'EX_fe3_e': 179.12078073238428,
#  'EX_lys__L_e': 3.4202617950464216,
#  'EX_ascb__L_e': 2.855247299250132,
#  'EX_asp__L_e': 0.3785160927630903,
#  'EX_phe__L_e': 2.4214661032883638,
#  'EX_k_e': 859.1166367847196,
#  'EX_pro__L_e': 6.080056978819687,
#  'EX_ca2_e': 0.7834722291531512,
#  'EX_cit_e': 9.038130276673115,
#  'EX_mg2_e': 15.881505862991157,
#  'EX_mn2_e': 182025.20839381815,
#  'EX_cobalt2_e': 169686.86580738873,
#  'EX_zn2_e': 153.0050466432176,
#  'EX_cu2_e': 157368.20570925003,
#  'EX_glu__L_e': 4.106175852729539,
#  'EX_fe2_e': 0.07162682424568,
#  'EX_gthrd_e': 0.0488090589613432,
#  'EX_gua_e': 0.037055172505062,
#  'EX_his__L_e': 1.0956807748241948,
#  'EX_ile__L_e': 1.8296169239565463,
#  'EX_inost_e': 0.0111014972145233,
#  'EX_lipoate_e': 0.0048704551469557,
#  'EX_met__L_e': 0.8377320970284101,
#  'EX_mobd_e': 0.0011879633056892,
#  'EX_nac_e': 0.0073709168192036,
#  'EX_pnto__R_e': 0.0054988592616461,
#  'EX_pydam_e': 0.0293756499362548,
#  'EX_pydxn_e': 0.0283721480080387,
#  'EX_so4_e': 0.3355068933498225,
#  'EX_trp__L_e': 0.9793107865305204,
#  'EX_tyr__L_e': 1.6557334904881973,
#  'EX_val__L_e': 5.975430055969292,
#  'EX_thm_e': 0.0018616498925362,
#  'EX_ura_e': 0.2051980410902832,
#  'EX_xan_e': 0.0249817534587566}

# %%
experiment.run()
# Out:
# Running COMETS simulation ...
# COMETSpy:  False
# 5e-06
# <class 'numpy.float64'>
# Model file:  model_file ./iMM904.cmd
#
# ['iMM904']
# Done!

# %%
media_df = experiment.media
media_df['t'] = media_df['cycle'] * 0.01

met_df = experiment.get_metabolite_time_series(upper_threshold=None)
met_df['t'] = met_df['cycle'] * 0.01

biomass_df = experiment.total_biomass
biomass_df['t'] = biomass_df['cycle'] * 0.01

t = biomass_df['t'].values
sol = np.zeros([len(t), len(comm.solution_keys)])

for idx, s in enumerate(comm.solution_keys):
    if s in comm.model_names:
        for t_val in t:
            t_idx = utils.find_nearest(biomass_df['t'].values, t_val)
            sol[:, idx][t_idx] = biomass_df[s].values[t_idx]

    else:
        s = s.replace('M_', '')
        s_df = met_df[[s, 't']]
        for t_val in t:
            t_idx = utils.find_nearest(s_df['t'].values, t_val)
            sol[:, idx][t_idx] = s_df[s].values[t_idx]

print(comm.solution_keys)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/59/mfl58qxj151bv31dsnfrs1lh0000gn/T/ipykernel_51968/2946353570.py in <module>
# ----> 1 media_df = experiment.media
#       2 media_df['t'] = media_df['cycle'] * 0.01
#       3
#       4 met_df = experiment.get_metabolite_time_series(upper_threshold=None)
#       5 met_df['t'] = met_df['cycle'] * 0.01
#
# NameError: name 'experiment' is not defined

# %%
ax = experiment.total_biomass.plot(x = 'cycle')
ax.set_ylabel("Biomass (gr.)")

# %%
print(comm.dynamic_compounds)

# %%
for x in (layout.media):
    print(x)

print(layout.media.loc[layout.media.metabolite == 'val__L_e'])

# %%
output_metabolites = df.keys()

for x in comm.dynamic_compounds:
    metabolite_str = x.replace('M_', '')

    if metabolite_str not in output_metabolites:
        print(metabolite_str)

# %%
media = experiment.media.copy()
# media = media[media.conc_mmol<900]
media = media.loc[media['metabolite'] == 'val__L_e']
fig, ax = plt.subplots()
media.groupby('metabolite').plot(x='cycle', ax =ax, y='conc_mmol')
ax.set_ylabel("Concentration (mmol)")

# %%
media.loc[media['metabolite'] == 'acald_e']
# Out:
# Empty DataFrame
# Columns: [metabolite, cycle, x, y, conc_mmol]
# Index: []

# %%
layout.media

# %%
for idx, x in layout.media.iterrows():
    print(x['metabolite'], x['g_static'])

# %%
layout.models.get_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/59/mfl58qxj151bv31dsnfrs1lh0000gn/T/ipykernel_43489/3122092231.py in <module>
# ----> 1 layout.models.get_crossfeeding_compounds()
#
# AttributeError: 'list' object has no attribute 'get_crossfeeding_compounds'
